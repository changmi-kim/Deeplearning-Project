# %%
import cv2

filepath = './data/line.mp4'
video = cv2.VideoCapture(filepath) #수정


if not video.isOpened():
    print("Video is unavailable :", filepath)
    exit(0)

length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
fps = video.get(cv2.CAP_PROP_FPS)
count = 0



while(video.isOpened()):
    ret, image = video.read()


    if(int(video.get(1)) % int(fps) == 0):
        cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
        print('Saved frame number :', str(video.get(1)))
        count += 1


    if int(video.get(1)) == length:
        video.release()
        break
# Out:
# Saved frame number : 30.0
# Saved frame number : 60.0
# Saved frame number : 90.0
# Saved frame number : 120.0
# Saved frame number : 150.0
# Saved frame number : 180.0
# Saved frame number : 210.0
# Saved frame number : 240.0
# Saved frame number : 270.0
# Saved frame number : 300.0
# Saved frame number : 330.0
# Saved frame number : 360.0
# Saved frame number : 390.0
# Saved frame number : 420.0
# Saved frame number : 450.0
# Saved frame number : 480.0
# Saved frame number : 510.0
# Saved frame number : 540.0
# Saved frame number : 570.0
# Saved frame number : 600.0
# Saved frame number : 630.0
# Saved frame number : 660.0
# Saved frame number : 690.0
# Saved frame number : 720.0
# Saved frame number : 750.0
# Saved frame number : 780.0
# Saved frame number : 810.0
# Saved frame number : 840.0
# Saved frame number : 870.0
# Saved frame number : 900.0
# Saved frame number : 930.0
# Saved frame number : 960.0
# Saved frame number : 990.0
# Saved frame number : 1020.0
# ...

# %%
from glob import glob

img_list = glob('./data/line/*.jpg')
label_list = glob('data/line_label/*.json')
print(len(img_list), len(label_list))
# Out:
# 100 100

# %%
# 터미널에서
# labelme2yolo  --json_dir ./data/line_label/ --val_size 0.15 --test_size 0.15

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="./data/line_label/YOLODataset/dataset.yaml", epochs=100)  # train the model
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 5927MiB)
# ...
